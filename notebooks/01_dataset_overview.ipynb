# %% [markdown]
# # FORCE 2020 Dataset Overview
#
#
# This notebook examines well data across the 118-well FORCE 2020 LAS collection
#
#
#
# #### Objectives:
# - what data exist?
# - where are the wells? What is the geometry
# -  how complete are the logs for each well?
#
# #### Primary references:
#
# - Bormann, P., Aursand, P., Dilib, F., Dischington, P., and Manral, S. (2020), FORCE Machine Learning Competition.
# - Zenodo dataset record: `https://zenodo.org/records/4351156`
# - FORCE competition repository: `https://github.com/bolgebrygg/Force-2020-Machine-Learning-competition`
# - FORCE competition overview and lithology key: `https://thinkonward.com/app/c/challenges/force-well-logs/overview`
# - CREWES Research Report, *Log Facies Classification Contest Pitfalls* (2020): `https://www.crewes.org/ForOurSponsors/ResearchReports/2020/CRR202018.pdf`

# %%
### imports
import os
from pathlib import Path

import lasio
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.ticker import FuncFormatter

import random
import sys


### pygmt imports
import pyproj
proj_path = os.path.join(sys.prefix, "share", "proj")
pyproj.datadir.set_data_dir(proj_path)
from pyproj import CRS, Transformer
import pygmt


try:
    import ipympl
except ImportError:
    # %pip install ipympl

try:
    import kaleido
except ImportError:
    # %pip install --upgrade "kaleido>=1"

from PIL import Image
import plotly.io as pio
from IPython.display import HTML, display
from plotly.subplots import make_subplots
import plotly.graph_objects as go

import ipywidgets as widgets

### pandas displays floats to 2dp for ease of reading
pd.set_option('display.float_format', lambda x: '%.2f' % x)
# Out:
# /Users/user/micromamba/envs/universal/lib/python3.10/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)

# %%
### establish unit conversions

FT_PER_M = 3.28084

# %%
### make plots interactive
# %matplotlib widget

### make plots static 
# %matplotlib inline

# %%
### set project paths 

cwd = Path.cwd()
project_dir = cwd.parent
data_root_dir = project_dir.parent / "data"

def list_contents(dir):
    print(f'\nELEMENTS IN /{os.path.basename(dir)}/:')
    print(f'{sorted(path.name for path in dir.iterdir())}')

list_contents(project_dir)
list_contents(data_root_dir)

data_dir = data_root_dir / 'force_2020_well_log_analysis' / 'Force_2020_all_wells'

LAS_FILES = sorted(data_dir.glob("*.las"))
print(f"LAS files found: {len(LAS_FILES)}")

list_contents(data_dir)
# Out:
# ELEMENTS IN /force_2020_well_log_analysis/:
# ['.DS_Store', '.git', '.venv', '.vscode', 'README.md', 'notebooks', 'outputs']
#
# ELEMENTS IN /data/:
# ['.DS_Store', 'force_2020_well_log_analysis', 'mid_atlantic_ridge_bathymetry_analysis']
# LAS files found: 118
#
# ELEMENTS IN /Force_2020_all_wells/:
# ['15_9-13.las', '15_9-14.las', '15_9-15.las', '15_9-17.las', '15_9-23.las', '16_1-2.las', '16_1-6 A.las', '16_10-1.las', '16_10-2.las', '16_10-3.las', '16_10-5.las', '16_11-1 ST3.las', '16_2-11 A.las', '16_2-16.las', '16_2-6.las', '16_2-7.las', '16_4-1.las', '16_5-3.las', '16_7-4.las', '16_7-5.las', '16_7-6.las', '16_8-1.las', '17_11-1.las', '17_4-1.las', '25_10-10.las', '25_10-9.las', '25_11-15.las', '25_11-19 S.las', '25_11-24.las', '25_11-5.las', '25_2-13 T4.las', '25_2-14.las', '25_2-7.las', '25_3-1.las', '25_4-5.las', '25_5-1.las', '25_5-3.las', '25_5-4.las', '25_6-1.las', '25_6-2.las', '25_6-3.las', '25_7-2.las', '25_8-5 S.las', '25_8-7.las', '25_9-1.las', '26_4-1.las', '29_3-1.las', '29_6-1.las', '30_3-3.las', '30_3-5 S.las', '30_6-5.las', '31_2-1.las', '31_2-10.las', '31_2-19 S.las', '31_2-21 S.las', '31_2-7.las', '31_2-8.las', '31_2-9.las', '31_3-1.las', '31_3-2.las', '31_3-3.las', '31_3-4.las', '31_4-10.las', '31_4-5.las', '31_5-4 S.las', '31_6-5.las', '31_6-8.las', '32_2-1.las', '33_5-2.las', '33_6-3 S.las', '33_9-1.las', '33_9-17.las', '34_10-16 R.las', '34_10-19.las', '34_10-21.las', '34_10-33.las', '34_10-35.las', '34_11-1.las', '34_11-2 S.las', '34_12-1.las', '34_2-4.las', '34_3-1 A.las', '34_3-2 S.las', '34_3-3 A.las', '34_4-10 R.las', '34_5-1 A.las', '34_5-1 S.las', '34_6-1 S.las', '34_7-13.las', '34_7-20.las', '34_7-21.las', '34_8-1.las', '34_8-3.las', '34_8-7 R.las', '35_11-1.las', '35_11-10.las', '35_11-11.las', '35_11-12.las', '35_11-13.las', '35_11-15 S.las', '35_11-5.las', '35_11-6.las', '35_11-7.las', '35_12-1.las', '35_3-7 S.las', '35_4-1.las', '35_6-2 S.las', '35_8-4.las', '35_8-6 S.las', '35_9-10 S.las', '35_9-2.las', '35_9-5.las', '35_9-6 S.las', '35_9-7.las', '35_9-8.las', '36_7-3.las', '7_1-1.las', '7_1-2 S.las']

# %%
### make well inventory

### get header values
def get_header_value(las, mnemonic):
    try:
        return las.well[mnemonic].value
    except (KeyError, AttributeError):
        return np.nan

well_records = []
curve_records = []

### iterate over each of 118 wells and get header values, curves and statistics
for path in LAS_FILES:
    try:
        ### get las file path
        las = lasio.read(path)
        df = las.df()

        depth = pd.to_numeric(
            pd.Series(df.index),
            errors="coerce",
        ).dropna().to_numpy()

        depth_difference = np.diff(depth)

        ### get mnemonic header value nd statistics
        well_name = get_header_value(las, "WELL")
        if pd.isna(well_name) or str(well_name).strip() == "":
            well_name = path.stem

        well_records.append(
            {
                "file": path.name,
                "well": str(well_name),
                "samples": len(df),
                "curves": len(df.columns),
                "depth_min": np.nanmin(depth) if len(depth) else np.nan,
                "depth_max": np.nanmax(depth) if len(depth) else np.nan,
                "median_step": (
                    np.nanmedian(np.abs(depth_difference))
                    if len(depth_difference)
                    else np.nan
                ),
                "duplicate_depths": int(df.index.duplicated().sum()),
                "depth_monotonic": bool(
                    np.all(depth_difference > 0)
                    or np.all(depth_difference < 0)
                ),
                "read_error": None,
            }
        )
        
        ### get individual curves and statistics
        for curve in las.curves[1:]:
            mnemonic = curve.mnemonic
            series = (
                pd.to_numeric(df[mnemonic], errors="coerce")
                if mnemonic in df.columns
                else pd.Series(dtype=float)
            )

            curve_records.append(
                {
                    "file": path.name,
                    "well": str(well_name),
                    "curve": mnemonic,
                    "unit": curve.unit,
                    "description": curve.descr,
                    "samples": len(series),
                    "valid_samples": int(series.notna().sum()),
                    "missing_pct": float(series.isna().mean() * 100),
                }
            )

    except Exception as error:
        well_records.append(
            {
                "file": path.name,
                "well": path.stem,
                "samples": np.nan,
                "curves": np.nan,
                "depth_min": np.nan,
                "depth_max": np.nan,
                "median_step": np.nan,
                "duplicate_depths": np.nan,
                "depth_monotonic": np.nan,
                "read_error": str(error),
            }
        )

# %%
### test well inventory
well_inventory = pd.DataFrame(well_records)
well_inventory
# Out:
#             file                        well  samples  curves  depth_min  \
# 0    15_9-13.las  15/9-13 Sleipner East Appr    21441      20      25.00
# 1    15_9-14.las                     15/9-14    22875      20      98.80
# 2    15_9-15.las              15/9-15 Gungne    20954      22      25.00
# 3    15_9-17.las                     15/9-17    19879      21     102.61
# 4    15_9-23.las         15/9-23 Skardkollen    20494      20     110.00
# ..           ...                         ...      ...     ...        ...
# 113   35_9-7.las                      35/9-7    17166      20     397.05
# 114   35_9-8.las                      35/9-8    18842      20     392.02
# 115   36_7-3.las                      36/7-3    16950      16     373.00
# 116    7_1-1.las                       7/1-1    17982      20      82.60
# 117  7_1-2 S.las                     7/1-2 S    19586      20     198.02
#
#      depth_max  median_step  duplicate_depths  depth_monotonic read_error
# 0      3283.88         0.15                 0             True       None
# 1      3575.65         0.15                 0             True       None
# 2      3209.86         0.15                 0             True       None
# 3      3124.07         0.15                 0             True       None
# 4      3224.94         0.15                 0             True       None
# ..         ...          ...               ...              ...        ...
# 113    3006.13         0.15                 0             True       None
# 114    3255.85         0.15                 0             True       None
# 115    2949.25         0.15                 0             True       None
# 116    2815.71         0.15                 0             True       None
# 117    3174.94         0.15                 0             True       None
#
# [118 rows x 10 columns]

# %%
### test curve inventory
curve_inventory = pd.DataFrame(curve_records)
curve_inventory
# Out:
#              file                        well  \
# 0     15_9-13.las  15/9-13 Sleipner East Appr
# 1     15_9-13.las  15/9-13 Sleipner East Appr
# 2     15_9-13.las  15/9-13 Sleipner East Appr
# 3     15_9-13.las  15/9-13 Sleipner East Appr
# 4     15_9-13.las  15/9-13 Sleipner East Appr
# ...           ...                         ...
# 2270  7_1-2 S.las                     7/1-2 S
# 2271  7_1-2 S.las                     7/1-2 S
# 2272  7_1-2 S.las                     7/1-2 S
# 2273  7_1-2 S.las                     7/1-2 S
# 2274  7_1-2 S.las                     7/1-2 S
#
#                                   curve   unit  \
# 0     FORCE_2020_LITHOFACIES_CONFIDENCE      _
# 1      FORCE_2020_LITHOFACIES_LITHOLOGY      _
# 2                                  CALI     in
# 3                             MUDWEIGHT      _
# 4                                   ROP    m/h
# ...                                 ...    ...
# 2270                               DRHO  g/cm3
# 2271                           DEPTH_MD      _
# 2272                              X_LOC      _
# 2273                              Y_LOC      _
# 2274                              Z_LOC      _
#
#                             description  samples  valid_samples  missing_pct
# 0     FORCE_2020_LITHOFACIES_CONFIDENCE    21441          18277        14.76
# 1      FORCE_2020_LITHOFACIES_LITHOLOGY    21441          18270        14.79
# 2                                  CALI    21441          18345        14.44
# 3                             MUDWEIGHT    21441          17520        18.29
# 4                                   ROP    21441          20297         5.34
# ...                                 ...      ...            ...          ...
# 2270                               DRHO    19586           1617        91.74
# 2271                           DEPTH_MD    19586          19544         0.21
# 2272                              x_loc    19586          19544         0.21
# 2273                              y_loc    19586          19544         0.21
# 2274                              z_loc    19586          19544         0.21
#
# [2275 rows x 8 columns]

# %%
# ### make an alphanumeric index for every curve
# curve_names = sorted(curve_inventory["curve"].dropna().unique())

# curve_index = {
#     curve: f"C{i:02d}"
#     for i, curve in enumerate(curve_names, start=1)
# }

# ### add the index to the curve inventory
# curve_inventory["curve_id"] = curve_inventory["curve"].map(curve_index)

# ### test
# curve_key = pd.DataFrame(
#     {
#         "curve_id": list(curve_index.values()),
#         "curve": list(curve_index.keys()),
#     }
# )
# curve_key

# %%
### find curve presence for each well
curve_presence = (
    curve_inventory
    .assign(present=True)
    .pivot_table(
        index="well",
        columns="curve",
        values="present",
        aggfunc="any",
        fill_value=False,
    )
    .astype(bool)
)
curve_presence
# Out:
# curve                          BS  CALI   DCAL  DEPTH_MD  DRHO   DTC    DTS  \
# well
# 15/9-13 Sleipner East Appr  False  True  False      True  True  True  False
# 15/9-14                     False  True  False      True  True  True  False
# 15/9-15 Gungne               True  True   True      True  True  True  False
# 15/9-17                     False  True  False      True  True  True  False
# 15/9-23 Skardkollen          True  True   True      True  True  True   True
# ...                           ...   ...    ...       ...   ...   ...    ...
# 35/9-7                       True  True  False      True  True  True   True
# 35/9-8                       True  True  False      True  True  True   True
# 36/7-3                      False  True  False      True  True  True  False
# 7/1-1                        True  True   True      True  True  True  False
# 7/1-2 S                      True  True  False      True  True  True   True
#
# curve                       FORCE_2020_LITHOFACIES_CONFIDENCE  \
# well
# 15/9-13 Sleipner East Appr                               True
# 15/9-14                                                  True
# 15/9-15 Gungne                                           True
# 15/9-17                                                  True
# 15/9-23 Skardkollen                                      True
# ...                                                       ...
# 35/9-7                                                   True
# 35/9-8                                                   True
# 36/7-3                                                   True
# 7/1-1                                                    True
# 7/1-2 S                                                  True
#
# curve                       FORCE_2020_LITHOFACIES_LITHOLOGY    GR  ...  \
# well                                                                ...
# 15/9-13 Sleipner East Appr                              True  True  ...
# 15/9-14                                                 True  True  ...
# 15/9-15 Gungne                                          True  True  ...
# 15/9-17                                                 True  True  ...
# 15/9-23 Skardkollen                                     True  True  ...
# ...                                                      ...   ...  ...
# 35/9-7                                                  True  True  ...
# 35/9-8                                                  True  True  ...
# 36/7-3                                                  True  True  ...
# 7/1-1                                                   True  True  ...
# 7/1-2 S                                                 True  True  ...
#
# curve                        RMIC    ROP   ROPA   RSHA    RXO    SGR     SP  \
# well
# 15/9-13 Sleipner East Appr  False   True  False   True   True  False   True
# 15/9-14                     False   True  False   True   True  False   True
# 15/9-15 Gungne              False   True  False   True   True  False   True
# 15/9-17                     False   True  False   True   True   True   True
# 15/9-23 Skardkollen         False   True   True  False  False  False  False
# ...                           ...    ...    ...    ...    ...    ...    ...
# 35/9-7                       True   True   True  False  False  False  False
# 35/9-8                       True   True   True  False  False  False  False
# 36/7-3                      False  False   True  False  False  False  False
# 7/1-1                       False   True  False   True  False  False   True
# 7/1-2 S                     False   True   True   True  False  False  False
#
# curve                       X_LOC  Y_LOC  Z_LOC
# well
# 15/9-13 Sleipner East Appr   True   True   True
# 15/9-14                      True   True   True
# 15/9-15 Gungne               True   True   True
# 15/9-17                      True   True   True
# 15/9-23 Skardkollen          True   True   True
# ...                           ...    ...    ...
# 35/9-7                       True   True   True
# 35/9-8                       True   True   True
# 36/7-3                       True   True   True
# 7/1-1                        True   True   True
# 7/1-2 S                      True   True   True
#
# [118 rows x 26 columns]

# %%
### curve availability accross wells
curve_availability = (
    curve_presence
    .sum()
    .sort_values(ascending=False)
    .rename("wells")
    .to_frame()
)

curve_availability["percentage"] = (
    curve_availability["wells"]
    / len(curve_presence)
    * 100
)
curve_availability
# Out:
#                                    wells  percentage
# curve
# RDEP                                 118      100.00
# FORCE_2020_LITHOFACIES_LITHOLOGY     118      100.00
# Y_LOC                                118      100.00
# X_LOC                                118      100.00
# RHOB                                 118      100.00
# CALI                                 118      100.00
# NPHI                                 118      100.00
# GR                                   118      100.00
# Z_LOC                                118      100.00
# FORCE_2020_LITHOFACIES_CONFIDENCE    118      100.00
# DEPTH_MD                             118      100.00
# DTC                                  118      100.00
# RMED                                 117       99.15
# DRHO                                 114       96.61
# PEF                                   88       74.58
# BS                                    83       70.34
# RSHA                                  82       69.49
# SP                                    76       64.41
# ROP                                   67       56.78
# DTS                                   46       38.98
# RXO                                   43       36.44
# ROPA                                  38       32.20
# RMIC                                  34       28.81
# MUDWEIGHT                             29       24.58
# DCAL                                  28       23.73
# SGR                                   14       11.86

# %%
def plot_matrix(matrix, discrete=False):
    plot_matrix = matrix.copy()

    ### binary availability is converted to percentage
    values = plot_matrix.to_numpy()
    finite_values = values[np.isfinite(values)]

    if len(finite_values) and np.all(np.isin(finite_values, [0, 1])):
        plot_matrix = plot_matrix * 100

    fig, ax = plt.subplots(figsize=(12, 20))

    ### configure colormap and norm based on the discrete parameter
    if discrete:
        # pad levels slightly past 0 and 100 to include exact boundary values
        cmap, norm = mcolors.from_levels_and_colors(
            levels=[-0.1, 50, 100.1], colors=["#d73027", "#1a9850"]
        )
        ticks = [0, 100]
    else:
        cmap = "RdYlGn"
        norm = None
        ticks = np.arange(0, 101, 10)

    image = ax.imshow(
        plot_matrix,
        aspect="auto",
        interpolation="nearest",
        cmap=cmap,
        norm=norm,
        vmin=None if discrete else 0,
        vmax=None if discrete else 100,
    )

    colorbar = fig.colorbar(
        image,
        ax=ax,
        ticks=ticks,
        pad=0.02,
    )
    colorbar.set_label("Availability (%)")

    ax.set_xticks(range(len(matrix.columns)))
    ax.set_xticklabels(matrix.columns)
    ax.tick_params(axis="x", rotation=-40)
    plt.setp(ax.get_xticklabels(), ha="left")

    ax.set_yticks(range(len(matrix.index)))
    ax.set_yticklabels(matrix.index)

    ax.set_xlabel("Curve")
    ax.set_ylabel("Well")
    ax.set_title("FORCE 2020 LAS Curve Availability")

    ax.set_xticks(
        [x - 0.5 for x in range(1, len(matrix.columns))],
        minor=True,
    )
    ax.set_yticks(
        [y - 0.5 for y in range(1, len(matrix.index))],
        minor=True,
    )
    ax.grid(
        which="minor",
        color="black",
        linestyle="-",
        linewidth=0.5,
    )
    ax.tick_params(which="minor", size=0)

    plt.tight_layout()
    plt.show()

# %%
### plot presence
sorted_curves = (
    curve_presence
    .sum()
    .sort_values(ascending=False)
    .index
)

### reorder curve_presence columns using the sorted curve names
curve_presence_matrix = curve_presence[sorted_curves].astype(int)
### curve either 0 or 1 
plot_matrix(curve_presence_matrix,discrete=True)

# %%
### measure how valid each curve is for each well
validity_matrix = (
    curve_inventory
    .pivot_table(
        index="well",
        columns="curve",
        values="missing_pct",
    )
)

sorted_curves = (
    (100 - validity_matrix)
    .sum()
    .sort_values(ascending=False)
    .index
)

### reorder validity matrix columns using the sorted curve names
validity_matrix = validity_matrix[sorted_curves]

### curve from 0 to 100
plot_matrix(validity_matrix)

# %%
### inspect well trajectory

def inspect_las_trajectory(las_input):
    print(f'{os.path.basename(las_input)}\n')
    ### verbose output
    single_las = lasio.read(las_input)
    
    ### selected output
    curve_names = [curve.mnemonic for curve in single_las.curves]
    print(f'CURVES:\n{curve_names}\n')

    for item in single_las.well:
        print(
            item.mnemonic,
            "=",
            item.value,
            item.unit,
            "|",
            item.descr,
        )

    ### read as pandas df, if x and y coordinates exist print them
        ### x = easting, y = northing
    df = single_las.df()

    ### get measured depth in feet
    df["MD_FT"] = df["DEPTH_MD"] * FT_PER_M

    required = ["DEPTH_MD", "X_LOC", "Y_LOC", "Z_LOC"]

    if all(column in df.columns for column in required):

        xy_check = pd.DataFrame(
            {
                "unique_x": [df["X_LOC"].nunique(dropna=True)],
                "unique_y": [df["Y_LOC"].nunique(dropna=True)],
                "x_min": [df["X_LOC"].min()],
                "x_max": [df["X_LOC"].max()],
                "y_min": [df["Y_LOC"].min()],
                "y_max": [df["Y_LOC"].max()],
            }
        )
        print(f'\nUnique location values:\n{xy_check}\n')

        ### finding: some wells are deviated, not perfectly vertical and so there is a trajectory that varies spatially, measured depth = depth along borehole
        trajectory = df[["DEPTH_MD", 
                        "MD_FT",
                         "X_LOC", 
                         "Y_LOC", 
                         "Z_LOC",
                         ]].dropna().copy()
        print(f'Trajectory null values:\n{trajectory.isna().sum()}')
        print(f'\nTrajectory describe:\n{trajectory.describe().round(2)}')

        first_point = trajectory.iloc[0]
        last_point = trajectory.iloc[-1]

        print(
        "\nFirst valid trajectory point"
        # f"\nMD: {first_point['DEPTH_MD']:.2f}"
        f"\nMD: {first_point['MD_FT']:.2f} ft"
        f"\nX:  {first_point['X_LOC']:.2f} m"
        f"\nY:  {first_point['Y_LOC']:.2f} m"
        f"\nZ:  {first_point['Z_LOC']:.2f} m"
        )

        print(
        "\nLast valid trajectory point"
        # f"\nMD: {last_point['DEPTH_MD']:.2f}"
        f"\nMD: {last_point['MD_FT']:.2f} ft"
        f"\nX:  {last_point['X_LOC']:.2f} m"
        f"\nY:  {last_point['Y_LOC']:.2f} m"
        f"\nZ:  {last_point['Z_LOC']:.2f} m"
        )

        ### 3d plot
        fig = plt.figure(figsize=(9, 8))
        ax = fig.add_subplot(111, projection="3d")

        ax.plot(
            trajectory["X_LOC"],
            trajectory["Y_LOC"],
            trajectory["Z_LOC"],
        )

        ax.scatter(
            trajectory["X_LOC"].iloc[0],
            trajectory["Y_LOC"].iloc[0],
            trajectory["Z_LOC"].iloc[0],
            label="First logged point",
        )

        ax.scatter(
            trajectory["X_LOC"].iloc[-1],
            trajectory["Y_LOC"].iloc[-1],
            trajectory["Z_LOC"].iloc[-1],
            label="Last logged point",
        )

        ax.set_xlabel("Easting (m)")
        ax.set_ylabel("Northing (m)")
        ### instead of earlier route of manually making a new column for z location calculated in ft, this route upholds the native values in meters and formats at the end in feet using matplotlib funcformatter so the values for northing and easting ae geometrically consistent with z location in feet.
        ax.zaxis.set_major_formatter(
        FuncFormatter(lambda value, position: f"{value * FT_PER_M:,.0f}"))
        
        ax.set_zlabel("Elevation (ft)")
        ax.set_title(f"{os.path.basename(las_input)} well trajectory")
        ax.legend()

        plt.tight_layout()
        plt.show()

    else:
        print("\nMISSING location curves")



### test with random las file
random_las = random.choice(LAS_FILES)
inspect_las_trajectory(random_las)
# Out:
# 35_11-7.las
#
# CURVES:
# ['DEPT', 'FORCE_2020_LITHOFACIES_CONFIDENCE', 'FORCE_2020_LITHOFACIES_LITHOLOGY', 'CALI', 'BS', 'RDEP', 'RSHA', 'RMED', 'SP', 'DTC', 'NPHI', 'PEF', 'GR', 'RHOB', 'DRHO', 'DEPTH_MD', 'X_LOC', 'Y_LOC', 'Z_LOC']
#
# STRT = 385.75 m |
# STOP = 2900.78125 m |
# STEP = 0.152 m |
# NULL = -999.25  |
# COMP =   | COMPANY
# WELL = 35/11-7  | WELL
# FLD =   | FIELD
# LOC =   | LOCATION
# SRVC =   | SERVICE COMPANY
# DATE = 2020-08-09 20:02:02   : Log Export Date {yyyy-MM-dd HH:mm  | ss}
# PROV =   | PROVINCE
# UWI = 35/11-7  | UNIQUE WELL ID
# API =   | API NUMBER
#
# Unique location values:
#    unique_x  unique_y     x_min     x_max      y_min      y_max
# 0       210        27 531911.88 531924.94 6766796.50 6766809.50
#
# Trajectory null values:
# DEPTH_MD    0
# MD_FT       0
# X_LOC       0
# Y_LOC       0
# Z_LOC       0
# dtype: int64
#
# Trajectory describe:
#        DEPTH_MD    MD_FT     X_LOC      Y_LOC    Z_LOC
# count  16542.00 16542.00  16542.00   16542.00 16542.00
# mean    1642.87  5389.98 531918.91 6766801.17 -1613.78
# std      725.86  2381.44      3.99       3.96   725.78
# min      385.75  1265.58 531911.88 6766796.50 -2870.67
# 25%     1014.31  3327.78 531915.44 6766798.00 -2242.29
# 50%     1642.87  5389.98 531918.94 6766799.50 -1613.82
# 75%     2271.42  7452.18 531922.69 6766804.00  -985.29
# max     2899.98  9514.38 531924.94 6766809.50  -356.75
#
# First valid trajectory point
# MD: 1265.58 ft
# X:  531912.06 m
# Y:  6766796.50 m
# Z:  -356.75 m
#
# Last valid trajectory point
# MD: 9514.38 ft
# X:  531923.06 m
# Y:  6766797.00 m
# Z:  -2870.67 m

# %%
tail_series = df['FORCE_2020_LITHOFACIES_LITHOLOGY']
print(tail_series[tail_series.notna()])
# Out:
# DEPT
# 2859.99   65000.00
# 2860.14   65000.00
# 2860.30   65000.00
# 2860.45   65000.00
# 2860.60   65000.00
#             ...
# 3169.46   65030.00
# 3169.62   65030.00
# 3169.77   65030.00
# 3169.92   65030.00
# 3170.07   65030.00
# Name: FORCE_2020_LITHOFACIES_LITHOLOGY, Length: 2041, dtype: float64

# %%
### plot all the wells in 2d map using pygmt

### make df to get only the shallowest records of a well for mapping
shallow_records = []

for path in LAS_FILES:
    las = lasio.read(path)
    df = las.df()

    required = ["DEPTH_MD", "X_LOC", "Y_LOC", "Z_LOC"]

    if not all(column in df.columns for column in required):
        continue

    location = (
        df[required]
        .dropna()
        .sort_values("DEPTH_MD")
    )

    if location.empty:
        continue

    shallowest = location.iloc[0]

    try:
        well_name = str(las.well["WELL"].value)
    except (KeyError, AttributeError):
        well_name = path.stem

    shallow_records.append(
        {
            "well": well_name,
            "file": path.name,
            "depth_md": shallowest["DEPTH_MD"],
            "easting": shallowest["X_LOC"],
            "northing": shallowest["Y_LOC"],
            "z": shallowest["Z_LOC"],
        }
    )

shallow_points = pd.DataFrame(shallow_records)


### convert from projected coordinate reference system to lat/long for pygmt to ingest

source_crs = CRS.from_epsg(23031)
map_crs = CRS.from_epsg(4326)

transformer = Transformer.from_crs(
    source_crs,
    map_crs,
    always_xy=True,
)

longitude, latitude = transformer.transform(
    shallow_points["easting"].to_numpy(),
    shallow_points["northing"].to_numpy(),
)

shallow_points["longitude"] = longitude
shallow_points["latitude"] = latitude

shallow_points[
    ["well", "easting", "northing", "longitude", "latitude"]
].head()


### find the map extent for all the wells and pad with margins 

well_bounds = [
    shallow_points["longitude"].min(),
    shallow_points["longitude"].max(),
    shallow_points["latitude"].min(),
    shallow_points["latitude"].max(),
]

longitude_margin = 0.75
latitude_margin = 0.4

map_region = [
    well_bounds[0] - longitude_margin,
    well_bounds[1] + longitude_margin,
    well_bounds[2] - 0.1,
    well_bounds[3] + latitude_margin,
]

### pygmt order is west,east,south,north
print(f'Map extent (degrees of arc):'
      f' Lon {map_region[0]:.2f} to {map_region[1]:.2f}, '
      f'Lat {map_region[2]:.2f} to {map_region[3]:.2f}'
      )



#### plot figure of all the wells

fig = pygmt.Figure()

fig.coast(
    region=map_region,
    projection="M7i",
    shorelines=True,
    borders="1/0.5p,black",  ### level 1 = national boundaries
    land="gray90",
    water="white",
    frame=["af"],
    ### nautical mile scale bar:
    ### L: specifies a map scale
    ### g<lon>/<lat>: anchor point for scale calculation
    ### +c<lat>: origin latitude where scale is exact
    ### +w<length>N: scale bar width in nautical miles (n = Nautical Miles)
    ### +f: gives scale bar style
    ### +l: adds a label (optional)
    map_scale="g4.0/57.8+c57.8+w50n+f+l",
)

fig.plot(
    x=shallow_points["longitude"],
    y=shallow_points["latitude"],
    style="c0.08i",
    pen="0.5p",
    fill="red",
)





### add Europe inset map
###   jTL = j (inside main map) T (top) L (left)
###   +w2.4i/1.7i = inset size
###   +o0.15i/0.15i = offset from border
inset_region=[-15, 30, 45, 70]
with fig.inset(
    position="jTL+w2.4i/1.7i+o0.15i/0.15i",
    box="+gwhite+p1p,black",
):
    fig.coast(
        region=inset_region,
        projection="M2.4i",
        land="gray80",
        water="aliceblue",
        borders="1/0.25p,gray50",
        shorelines="0.5p,black",
        # frame="g",
        
    )

    ### highlight the main map boundary inside the inset
    fig.plot(
        data=[[
            map_region[0],
            map_region[2],
            map_region[1],
            map_region[3],
        ]],
        style="r+s",
        pen="1.5p,red",
        region=inset_region,
        projection="M2.4i",
    )

# fig.show()

well_map_fig = fig

### output the basemap for other uses later
map_floor_path = project_dir / Path("outputs") / "force_2020_map_floor.png"
map_floor_path.parent.mkdir(parents=True, exist_ok=True)

map_floor = pygmt.Figure()

map_floor.coast(
    region=map_region,
    projection="M7i",
    shorelines="0.5p,black",
    borders="1/0.5p,black",
    land="gray90",
    water="white",
)

### add well location points
map_floor.plot(
    x=shallow_points["longitude"],
    y=shallow_points["latitude"],
    style="c0.08i",
    pen="0.5p",
    fill="red",
)

map_floor.basemap(
    frame="f",
)

map_floor.savefig(
    str(map_floor_path),
    dpi=300, ### pixel resolution
    crop=True,
)

# map_floor.show()
# Out:
# Map extent (degrees of arc): Lon 0.87 to 5.08, Lat 57.70 to 62.23

# %%
### well trajectory plotting

### horizontal exaggeration to show well trajectory deviations despite working at large x y scales
horizontal_exaggeration = 30
max_points_per_well = 80

trajectory_records = []

for path in LAS_FILES:
    las = lasio.read(path)
    df = las.df()

    required = ["DEPTH_MD", "X_LOC", "Y_LOC", "Z_LOC"]

    if not all(column in df.columns for column in required):
        continue

    trajectory = (
        df[required]
        .dropna()
        .sort_values("DEPTH_MD")
        .copy()
    )

    if trajectory.empty:
        continue

    try:
        well_name = str(las.well["WELL"].value)
    except (KeyError, AttributeError):
        well_name = path.stem

    ### reduce plotting load while retaining trajectory shape
    if len(trajectory) > max_points_per_well:
        sample_index = np.linspace(
            0,
            len(trajectory) - 1,
            max_points_per_well,
            dtype=int,
        )
        trajectory = trajectory.iloc[np.unique(sample_index)].copy()

    ### use the first logged trajectory point as the exaggeration anchor, effectively pseudo wellhead
    x_anchor = trajectory["X_LOC"].iloc[0]
    y_anchor = trajectory["Y_LOC"].iloc[0]

    ### preserve regional position while exaggerating the deviation
    trajectory["X_EXAG"] = (
        x_anchor
        + horizontal_exaggeration
        * (trajectory["X_LOC"] - x_anchor)
    )

    trajectory["Y_EXAG"] = (
        y_anchor
        + horizontal_exaggeration
        * (trajectory["Y_LOC"] - y_anchor)
    )

    ### make customary unit display fields
    trajectory["MD_FT"] = trajectory["DEPTH_MD"] * FT_PER_M
    trajectory["Z_FT"] = trajectory["Z_LOC"] * FT_PER_M

    trajectory["E_DEV_FT"] = (
        trajectory["X_LOC"] - x_anchor
    ) * FT_PER_M

    trajectory["N_DEV_FT"] = (
        trajectory["Y_LOC"] - y_anchor
    ) * FT_PER_M

    trajectory["H_DEV_FT"] = np.hypot(
        trajectory["E_DEV_FT"],
        trajectory["N_DEV_FT"],
    )

    trajectory["well"] = well_name

    trajectory_records.append(trajectory)

trajectories = pd.concat(
    trajectory_records,
    ignore_index=True,
)

print("Plotting points:", len(trajectories))

regional_x0 = trajectories["X_EXAG"].min()
regional_y0 = trajectories["Y_EXAG"].min()

trajectories["X_EXAG_FT"] = (
    trajectories["X_EXAG"] - regional_x0
) * FT_PER_M

trajectories["Y_EXAG_FT"] = (
    trajectories["Y_EXAG"] - regional_y0
) * FT_PER_M





### plotting
fig = go.Figure()

x_span = trajectories["X_EXAG_FT"].max() - trajectories["X_EXAG_FT"].min()
y_span = trajectories["Y_EXAG_FT"].max() - trajectories["Y_EXAG_FT"].min()

xy_max_span = max(x_span, y_span)

x_aspect = x_span / xy_max_span
y_aspect = y_span / xy_max_span

### basemap logic adds image ###

### align the geographic map to surface well locations only
trajectory_heads = (
    trajectories
    .sort_values("DEPTH_MD")
    .groupby("well", as_index=False)
    .first()
)

x_scale, x_offset = np.polyfit(
    trajectory_heads["X_LOC"],
    trajectory_heads["X_EXAG_FT"],
    1,
)

y_scale, y_offset = np.polyfit(
    trajectory_heads["Y_LOC"],
    trajectory_heads["Y_EXAG_FT"],
    1,
)

### load and reduce the pygmt map texture
map_image = Image.open(
    map_floor_path
).convert("RGB")

### pixel count
texture_width = 400

texture_height = round(
    map_image.height
    * texture_width
    / map_image.width
)

map_image = map_image.resize(
    (texture_width, texture_height),
    Image.Resampling.BILINEAR,
)

map_rgb = np.asarray(map_image)

n_rows, n_columns = map_rgb.shape[:2]

### remake the mercator coordinates represented by the image
mercator_crs = CRS.from_proj4(
    "+proj=merc +datum=WGS84 +units=m +no_defs"
)

to_mercator = Transformer.from_crs(
    map_crs,
    mercator_crs,
    always_xy=True,
)

from_mercator = Transformer.from_crs(
    mercator_crs,
    map_crs,
    always_xy=True,
)

west, east, south, north = map_region
mercator_west, _ = to_mercator.transform(west,0,)
mercator_east, _ = to_mercator.transform(east,0,)
_, mercator_south = to_mercator.transform(0,south,)
_, mercator_north = to_mercator.transform(0,north,)

mercator_x = np.linspace(
    mercator_west,
    mercator_east,
    n_columns + 1,
)

mercator_y = np.linspace(
    mercator_north,
    mercator_south,
    n_rows + 1,
)

mercator_x_grid, mercator_y_grid = np.meshgrid(
    mercator_x,
    mercator_y,
)

longitude_grid, latitude_grid = (
    from_mercator.transform(
        mercator_x_grid,
        mercator_y_grid,
    )
)

### transform the map grid into the source well coordinate system
to_source = Transformer.from_crs(
    map_crs,
    source_crs,
    always_xy=True,
)

easting_grid, northing_grid = to_source.transform(
    longitude_grid,
    latitude_grid,
)

map_x_grid = (
    x_scale * easting_grid
    + x_offset
)

map_y_grid = (
    y_scale * northing_grid
    + y_offset
)

### set the map at the top
z_span = (trajectories["Z_FT"].max() - trajectories["Z_FT"].min())
wellhead_z = 0.0
map_offset_ft = 400.0 ### control how shallow/deep basemap is
map_headroom_ft = 2000.0

map_z = wellhead_z + map_offset_ft
z_axis_max = map_z + map_headroom_ft

### make two colored triangles for every raster cell
vertex_index = np.arange(
    (n_rows + 1) * (n_columns + 1)
).reshape(
    n_rows + 1,
    n_columns + 1,
)

v00 = vertex_index[:-1, :-1].ravel()
v10 = vertex_index[1:, :-1].ravel()
v11 = vertex_index[1:, 1:].ravel()
v01 = vertex_index[:-1, 1:].ravel()

mesh_i = np.column_stack(
    [v00, v00]
).ravel()

mesh_j = np.column_stack(
    [v10, v11]
).ravel()

mesh_k = np.column_stack(
    [v11, v01]
).ravel()

### change basemap opacity
basemap_opacity = 0.25
linework_threshold = 190

pixel_colors = np.array(
    [
        f"rgb({red},{green},{blue})"
        for red, green, blue
        in map_rgb.reshape(-1, 3)
    ]
)

face_colors = np.repeat(
    pixel_colors,
    2,
)

### select dark map pixels such as coastlines, borders, and the frame
linework_pixels = (
    map_rgb.astype(float).mean(axis=2).ravel()
    < linework_threshold
)

linework_faces = np.repeat(
    linework_pixels,
    2,
)

### add the pygmt raster as the top plane
fig.add_trace(
    go.Mesh3d(
        x=map_x_grid.ravel(),
        y=map_y_grid.ravel(),
        z=np.full(
            map_x_grid.size,
            map_z,
        ),
        i=mesh_i,
        j=mesh_j,
        k=mesh_k,
        facecolor=face_colors,
        flatshading=True,
        opacity=basemap_opacity,
        lighting=dict(
            ambient=1,
            diffuse=0,
            specular=0,
            roughness=1,
            fresnel=0,
        ),
        hoverinfo="skip",
        showlegend=False,
        name="PyGMT map",
    )
)
### redraw dark cartographic linework above the translucent basemap
linework_z = map_z + 10.0
fig.add_trace(
    go.Mesh3d(
        x=map_x_grid.ravel(),
        y=map_y_grid.ravel(),
        z=np.full(
            map_x_grid.size,
            linework_z,
        ),
        i=mesh_i[linework_faces],
        j=mesh_j[linework_faces],
        k=mesh_k[linework_faces],
        facecolor=face_colors[linework_faces],
        flatshading=True,
        opacity=1.0,
        lighting=dict(
            ambient=1,
            diffuse=0,
            specular=0,
            roughness=1,
            fresnel=0,
        ),
        hoverinfo="skip",
        showlegend=False,
        name="PyGMT linework",
    )
)
### end - basemap logic adds image ###


### iterate over wells df to add each well trace 
for well, trajectory in trajectories.groupby("well"):
    customdata = np.column_stack(
        [
            trajectory["DEPTH_MD"],
            trajectory["MD_FT"],
            trajectory["X_LOC"],
            trajectory["Y_LOC"],
            trajectory["Z_LOC"],
            trajectory["H_DEV_FT"],
        ]
    )

    fig.add_trace(
        go.Scatter3d(
            x=trajectory["X_EXAG_FT"],
            y=trajectory["Y_EXAG_FT"],
            z=trajectory["Z_FT"],
            mode="lines",
            name=well,
            customdata=customdata,
            hovertemplate=(
                f"<b>{well}</b><br>"
                "MD: %{customdata[1]:,.0f} ft<br>"
                "Elevation: %{z:,.0f} ft<br>"
                "Horizontal deviation: %{customdata[5]:,.0f} ft<br>"
                "Easting: %{customdata[2]:,.1f}<br>"
                "Northing: %{customdata[3]:,.1f}"
                "<extra></extra>"
            ),
            showlegend=False,
        )
    )


### main plot
fig.update_layout(
    title=dict(
        text=(
            "FORCE 2020 well trajectories "
            f"({horizontal_exaggeration}x horizontal exaggeration)"
        ),
        x=0.5,
        xanchor="center",
        xref="container",
        font=dict(
            family="Arial, sans-serif",
            size=21,
        ),
    ),

    scene=dict(
        xaxis_title="Easting (ft)",
        yaxis_title="Northing (ft)",
        zaxis=dict(
            title="Elevation (ft)",
            range=[
                trajectories["Z_FT"].min(),
                z_axis_max,
            ],
            autorange=False,
        ),
        ### hide overlapping elevation axis
        # zaxis=dict(
        #     showticklabels=False,  ### hides overlapping z-axis tick numbers
        # ),
        aspectmode="manual",
        aspectratio=dict(
            x=x_aspect,
            y=y_aspect,
            z=0.15, ### critical control of how much vertical room the elevation axis takes up in 3d plot
        ),
        ### orbit or turntable work as dragmode parameter
        dragmode="turntable",

        ### get top down view (2d map style)#
        # camera = dict(
        # # projection=dict(type="orthographic"),
        # eye=dict(x=0, y=0, z=2),  ### positioned directly above origin on z-axis
        # up=dict(x=1, y=0, z=0),     ### top of screen points along positive x-axis
        # center=dict(x=0, y=0, z=0)  ### looking directly at origin
        # )
        ### get cmaera oblique view
        camera=dict(
            projection=dict(type="perspective"),
            eye=dict(x=0.5, y=-1, z=0.5),
            # eye=dict(x=0.95, y=-0.65, z=0.35),
            up=dict(x=0, y=0, z=1),
            center=dict(x=0, y=0, z=0),
        ),
    ),
    
    height=850,
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=50,
    ),
)

trajectory_fig = fig
# Out:
# Plotting points: 9440

# %%
# ### interactive visualization of 2d and 3d plots side by side ###

# title_style = """
#     font-family: Arial, sans-serif;
#     font-size: 20px;
#     font-weight: 600;
#     line-height: 1.2;
#     text-align: center;
#     padding: 5px 4px 7px 4px;
#     margin: 0;
#     white-space: nowrap;
# """

# ### make matching titles outside the plotting libraries
# map_title = widgets.HTML(
#     value=(
#         f'<div style="{title_style}">'
#         "FORCE 2020 well locations"
#         "</div>"
#     ),
#     layout=widgets.Layout(
#         width="100%",
#     ),
# )
# trajectory_title = widgets.HTML(
#     value=(
#         f'<div style="{title_style}">'
#         "FORCE 2020 well trajectories "
#         f"({horizontal_exaggeration}x horizontal exaggeration)"
#         "</div>"
#     ),
#     layout=widgets.Layout(
#         width="100%",
#     ),
# )

# ### make output containers for the original figures
# map_output = widgets.Output(
#     layout=widgets.Layout(
#         width="100%",
#         overflow="visible",
#     )
# )
# trajectory_output = widgets.Output(
#     layout=widgets.Layout(
#         width="100%",
#         overflow="hidden",
#     )
# )

# ### withdraw the internal plotly title and unnecessary whitespace
# trajectory_fig.update_layout(
#     title=None,
#     autosize=True,
#     width=None,
#     margin=dict(
#         l=0,
#         r=0,
#         b=0,
#         t=0,
#     ),
# )

# ### for true centered
# # trajectory_fig.update_scenes(
# #     domain=dict(
# #         x=[0.00, 1.00],
# #         y=[0.00, 1.00],
# #     ),
# # )
# ### for right adjusted to account for oblique view 
# trajectory_fig.update_scenes(
#     domain=dict(
#         x=[0.07, 0.99],
#         y=[0.00, 1.00],
#     ),
# )

# ### draw the complete pygmt figure
# with map_output:
#     well_map_fig.show(
#         width=380,
#     )

# ### draw the interactive plotly figure
# with trajectory_output:
#     trajectory_fig.show(
#         config={
#             "scrollZoom": True,
#             "responsive": True,
#         }
#     )

# ### group each title with its corresponding figure
# map_panel = widgets.VBox(
#     [
#         map_title,
#         map_output,
#     ],
#     layout=widgets.Layout(
#         width="30%",
#         border="1px solid black",
#         padding="0 5px 5px 5px",
#         box_sizing="border-box",
#         align_items="center",
#         min_width="0",
#     ),
# )

# trajectory_panel = widgets.VBox(
#     [
#         trajectory_title,
#         trajectory_output,
#     ],
#     layout=widgets.Layout(
#         width="70%",
#         border="1px solid black",
#         padding="0 5px 5px 5px",
#         box_sizing="border-box",
#         align_items="stretch",
#         min_width="0",
#     ),
# )

# ### set both complete panels on the same row
# side_by_side = widgets.HBox(
#     [
#         map_panel,
#         trajectory_panel,
#     ],
#     layout=widgets.Layout(
#         width="100%",
#         gap="8px",
#         align_items="stretch",
#     ),
# )

# display(side_by_side)




### static visualization of 2d and 3d plots side by side ###

### make static portfolio version of 2d and 3d plots
static_dir = project_dir / "outputs"
static_dir.mkdir(parents=True, exist_ok=True)

map_static_path = static_dir / "force_2020_well_locations.png"
trajectory_static_path = static_dir / "force_2020_well_trajectories.png"
overview_static_path = static_dir / "force_2020_dataset_overview.png"

### save the complete pygmt map
well_map_fig.savefig(
    str(map_static_path),
    dpi=300,
    crop=True,
)

### make a static copy without modifying the interactive figure
static_trajectory_fig = go.Figure(trajectory_fig)

static_trajectory_fig.update_layout(
    title=None,
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0,
    ),
)

### export the plotly figure as a static image
static_trajectory_fig.write_image(
    str(trajectory_static_path),
    width=1400,
    height=850,
    scale=2,
)

### read both static figures
map_static = plt.imread(map_static_path)
trajectory_static = plt.imread(trajectory_static_path)

### remake the existing 30:70 presentation
static_fig, static_axes = plt.subplots(
    1,
    2,
    figsize=(18, 8),
    gridspec_kw={"width_ratios": [3, 7]},
)

static_axes[0].imshow(map_static)
static_axes[0].set_title("FORCE 2020 well locations")
static_axes[0].axis("off")

static_axes[1].imshow(trajectory_static)
static_axes[1].set_title(
    "FORCE 2020 well trajectories "
    f"({horizontal_exaggeration}x horizontal exaggeration)"
)
static_axes[1].axis("off")

static_fig.tight_layout()

static_fig.savefig(
    overview_static_path,
    dpi=200,
    bbox_inches="tight",
)

plt.show()
